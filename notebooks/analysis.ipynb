# %%
import pandas as pd
import os

# Caminho relativo para pegar o arquivo parquet da pasta processed
filepath = os.path.join('..', 'data', 'processed', 'movies_processed.parquet')

# Lendo o arquivo Parquet
df = pd.read_parquet(filepath)

# Exibindo as primeiras linhas e informações básicas
display(df.head())
print(f"\nTotal de filmes: {df.shape[0]}")
print(f"Total de colunas: {df.shape[1]}")
# Out:
#         id        title release_date  popularity  vote_average  vote_count  \
# 0  1265609  War Machine   2026-02-12    699.9604         7.227         569
# 1  1290821      Shelter   2026-01-28    309.9837         6.700         274
# 2   799882    The Bluff   2026-02-17    225.3583         6.300         235
# 3  1193501      Whistle   2026-01-20    149.9649         6.125         124
# 4  1327819      Hoppers   2026-03-04    146.8322         7.800         144
#
#   original_language  release_year  decade
# 0                en          2026    2020
# 1                en          2026    2020
# 2                en          2026    2020
# 3                en          2026    2020
# 4                en          2026    2020
# Total de filmes: 20
# Total de colunas: 9
